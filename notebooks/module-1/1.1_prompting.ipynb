# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_deepseek import ChatDeepSeek

model = ChatDeepSeek(model="deepseek-chat")

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage



agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun and imaginative question! Since the moon doesn't have an atmosphere, water, or any form of government, it doesn't have a capital city in the literal sense.
#
# However, the concept of a "capital of the moon" is a popular theme in science fiction. In different stories, it might be called **Tycho City** (named after the Tycho crater), **Clavius**, or **Aristarchus**.
#
# In a more playful or metaphorical sense, if we were to name one, some people humorously suggest **Punxsutawney** (as a nod to the "groundhog" moon, though that's a stretch!) or simply **Mare Tranquillitatis** (the Sea of Tranquility, where humans first landed).
#
# But as a space scientist might tell you: scientifically, the moon has no capital.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the moon, as established by the first lunar settlements during the late 21st century, is **Ariana**—a vast, pressurized domed metropolis nestled in the Sea of Tranquility, near the site of the original Apollo 11 landing. Its name honors both the word for "silver" (a nod to the moon's pale glow) and the ancient concept of a harmonious, aspirational society. Ariana is built in concentric rings, with a central spire called the Heliostat that channels and focuses sunlight deep into its core, powering the city's fusion-lights and hydroponic forests. The city is known for its silent transit tubes, bio-luminescent parks, and the Hall of First Steps, a museum dedicated to humanity's leap beyond Earth.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaris Prime

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Mare Imbrium Station (often called "The Silver Cloister")
#
# Location: Burrowed into the edge of the Mare Imbrium, the lunar Sea of Rains, at the terminus of a vast lava tube network that provides natural radiation shielding. It overlooks the stark, ancient craters below.
#
# Vibe: Silent opulence, monastic surveillance
#
# Economy: Ultra-high-fidelity crystal manufacturing (for quantum computing components), private data storage vaults for Earth-bound corporations, and luxury zero-gravity botanical export (Moon-grown orchids and rare fungi are the ultimate status symbol).
#
# **Key District:** The Atrium of Quiet Echoes. It's a pressurized, domed park where the only sounds are the whisper of air recyclers and the faint, high-pitched chime of the city's patented "silence generators" that damper all chaotic noise.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunar Prime', location='The Mare Imbrium basin, near the lunar equator', vibe='Silent, ethereal, resilient — a city of pressurized domes and glittering spires against a black velvet sky', economy='Helium-3 mining, zero-g manufacturing, space tourism, quantum communications hub')

# %%
response["structured_response"].name
# Out:
# 'Lunar Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunar Prime is a city located at The Mare Imbrium basin, near the lunar equator
