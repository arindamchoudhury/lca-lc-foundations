# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

# Must specify provider — Ollama names aren't auto-inferred
model = init_chat_model("qwen3.5:4b", model_provider="ollama")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital city. It is not a country, and under international space law (specifically the Outer Space Treaty of 1967), no nation has the right to claim sovereignty over it.', additional_kwargs={}, response_metadata={'model': 'qwen3.5:4b', 'created_at': '2026-05-30T10:29:07.5413653Z', 'done': True, 'done_reason': 'stop', 'total_duration': 33374796400, 'load_duration': 236284800, 'prompt_eval_count': 18, 'prompt_eval_duration': 268214000, 'eval_count': 729, 'eval_duration': 32441369000, 'logprobs': None, 'model_name': 'qwen3.5:4b', 'model_provider': 'ollama'}, id='lc_run--019e786d-acf4-7bb0-aa1a-1ef2a9ff9cd3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 729, 'total_tokens': 747})

# %%
print(response.content)
# Out:
# The Moon does not have a capital city. It is not a country, and under international space law (specifically the Outer Space Treaty of 1967), no nation has the right to claim sovereignty over it.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-05-30T10:29:07.5413653Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 729,
#  'eval_duration': 32441369000,
#  'load_duration': 236284800,
#  'logprobs': None,
#  'model': 'qwen3.5:4b',
#  'model_name': 'qwen3.5:4b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': 268214000,
#  'total_duration': 33374796400}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="qwen3.5:4b",
    model_provider="ollama",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There is no capital of the Moon.
#
# The Moon is a natural satellite, not a country, so it has no government, cities, or administrative center.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="qwen3.5:4b")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There is **no capital city on the Moon**.
#
# The Moon is a natural satellite, not a sovereign nation. Therefore, it does not have a government, no citizens, and no capital city. While humans have visited the Moon in the past and currently have plans to establish lunar bases (such as under the Artemis program), there are no permanent human settlements or cities to speak of.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='39ce510b-fbba-4a28-9873-1808fc36059b'),
# ...

# %%
print(response['messages'][-1].content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite and is not a sovereign state, so it does not have a government, a president, or a capital city.
#
# Additionally, there are currently no permanent human residents or cities on the Moon. While human astronauts have visited there, none of them have made it home permanently.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1491ecb0-d4d3-4134-b663-f3fb2e84066f'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='489993fd-12e8-4e7b-87cd-6c21c2a36573', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='445d1814-f4ff-471e-84cf-70fccce50c77'),
# ...

# %% [markdown]
# ## Streaming Output

# %%
# Qwen3 enables thinking mode by default — streaming chunks have content=""
# during the thinking phase, so nothing prints. Disable it for streaming.
model = ChatOllama(model="qwen3.5:4b", think=False)
agent = create_agent(model=model)

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
