# %% [markdown]
# ## Basic prompting

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="qwen3.5:4b")

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage



agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There is **no capital city on the Moon**.
#
# The Moon is a natural satellite, not a country or nation. It does not have a government, cities, a population, or infrastructure. While there are various scientific names for features on the Moon (such as the *Sea of Tranquility* or *Tycho crater*), none function as a capital.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Currently, there is no official capital city on the Moon. The Moon has never been colonized in a way that established a permanent sovereign government or a seat of political power. However, as a science fiction world-builder, I have designed a fictional capital for a future lunar settlement in my latest project.
#
# Here is the concept I created:
#
# ### **The City: Selarion**
# **Location:** Shackleton Crater, South Pole
# **Population:** 12 million (mixed species)
# **Government:** The Council of the Tides
#
# **Architecture & Landscape:**
# Selarion does not sit *on* the surface but is buried within it. It is a "crater-city," utilizing the geodesic domes and thermal tunnels of the Moon's crust. The architecture mimics the "silica-skeleton" of a spiderweb, glowing with bioluminescent algae grown in the regolith gardens. It connects to Earth via the **Lunar Relay**, a massive, transparent fiber-optic tower that serves as both an antenna and a symbol of the city's connection to its world.
#
# **Governance:**
# Since the Moon is not a nation, but a resource, the government is known as the Council of the Tides. They represent the three major "tides" of lunar life: **Mining**, **Energy**, and **Expedition**. Decisions are made via consensus algorithms that simulate 200,000 possible futures based on the Moon's resource extraction capabilities.
#
# **The Central Spire:**
# The physical capital is the **Aethelgard**, a floating habitat station 50 meters above the surface. It uses magnetic levitation to hover in zero gravity, allowing for "sky-cities" above the dark sky, where solar collectors track the Sun around the lunar horizon.
#
# **Why "Selarion"?**
# The name combines *Selene* (Greek goddess of the Moon) and *Lion* (symbolizing the Council's strength), representing the Moon's "lion's share" of future humanity's destiny.
#
# Is this the direction you want to explore? I can flesh out the history, the challenges, or the political conflicts within Selarion.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: Lunovia

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: The Moon (Near the Shackleton Crater)
# Vibe: Cold, Crystalline, Electric
# Economy: Helium-3 Mining, Deep Space Logistics, Xenotech R&D

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='The Luminous Spires', location="Orbiting the Moon's South Pole", vibe='Futuristic, Ethereal, Glowing', economy='Resource Extraction, High-Tech Manufacturing, Tourism')

# %%
response["structured_response"].name
# Out:
# 'The Luminous Spires'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# The Luminous Spires is a city located at Orbiting the Moon's South Pole
