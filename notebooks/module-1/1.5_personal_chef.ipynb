# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_deepseek import ChatDeepSeek

model = ChatDeepSeek(model="deepseek-chat")

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Here are some fantastic recipe ideas you can make with leftover chicken and rice! Let me know if any catch your interest and I'll give you the full details.
#
# ---
#
# ## 🍳 Recipe Ideas for Leftover Chicken & Rice
#
# ### 1. **Chicken Fried Rice** ⭐ (Most Popular)
# A quick one-pan meal that beats takeout! Just stir-fry your chicken and rice with veggies, soy sauce, and eggs.
# - **Key ingredients you may need:** Soy sauce, eggs, frozen peas & carrots, garlic, sesame oil
# - ⏱ Time: ~15-20 minutes
#
# ### 2. **Chicken & Rice Casserole**
# A creamy, cheesy comfort food classic. Mix your chicken and rice with cream of chicken soup, veggies, and cheese, then bake with breadcrumbs on top.
# - **Key ingredients you may need:** Cream of chicken soup, cheese, peas, breadcrumbs/butter topping
# - ⏱ Time: ~30-40 minutes
#
# ### 3. **Chicken & Rice Soup**
# Warm, soothing, and easy! Simmer your chicken and rice in broth with carrots, celery, and onion for a hearty soup.
# - **Key ingredients you may need:** Chicken broth, carrots, celery, onion, garlic
# - ⏱ Time: ~20-25 minutes
#
# ### 4. **Chicken Rice Bowl**
# Layer your chicken and rice with your favorite toppings — avocado, salsa, black beans, cheese, sour cream, or roasted veggies.
# - **Key ingredients you may need:** Whatever toppings you have on hand!
# - ⏱ Time: ~5-10 minutes (no cooking required)
#
# ### 5. **Chicken Rice Stuffed Peppers**
# Mix chicken, rice, cheese, and spices, stuff into bell peppers, and bake.
# - **Key ingredients you may need:** Bell peppers, cheese, tomato sauce, onion
# - ⏱ Time: ~30-40 minutes
#
# ---
#
# Do any of these sound good to you? I can pull up the **full recipe instructions** for whichever one you'd like to make! Also, let me know if you have any other ingredients on hand (veggies, spices, sauces, etc.) and I can tailor the suggestions even more.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='279f3279-11e2-4529-b281-4118c5ca4cbc'),
#               AIMessage(content='Great question! Let me search for some delicious recipes using chicken and rice.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 344, 'total_tokens': 408, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 344}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '3b4e412f-7086-4c98-9976-ad168a14107e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e79db-e27e-7ab2-8c8d-38a3a810ddd5-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'easy recipes with leftover chicken and rice'}, 'id': 'call_00_iNkw5TvgsNGIq6fjJ7ak5294', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 344, 'output_tokens': 64, 'total_tokens': 408, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "easy recipes with leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Ingredients: 2 cups cooked rice (preferably day-old) 1 lb chicken breast, diced 2 eggs, beaten 1 cup peas and carrots (frozen is fine) 3 green", "score": 0.9073207, "raw_content": null}, {"url": "https://www.facebook.com/groups/1522233111383384/posts/3726155944324412", "title": "Leftover chicken and rice recipe - Facebook", "content": "Dice the leftover chicken while boiling the rice. Put a cup of milk in a saucepan and add a can of cream of chicken soup. As milk/soup mixture", "score": 0.8978479, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8868231, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Home | Recipe Index | Savory | Casserole | Chicken and Rice Casserole. # Chicken and Rice Casserole. This is the best chicken and rice recipe because it’s easy to make with simple ingredients that you can switch up depending on your tastes. It’s what I consider a “leftover” recipe because I use leftover chicken and rice to make it. ## Ingredients for Chicken and Rice Casserole. ## How to make Chicken and Rice Casserole. ## FAQ about this Easy Chicken Rice Casserole. For my chicken and rice casserole you will want to use cooked chicken. ## Chicken and Rice Casserole. Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Easy Chicken and Rice Casserole is a cheesy, creamy baked casserole with condensed soup, peas and chicken. ### Chicken and Rice Casserole.", "score": 0.8765607, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.8524574, "raw_content": null}], "response_time": 0.81, "request_id": "9252427c-81a6-4bfe-b417-dcfe161963b1"}', name='web_search', id='2cba78a2-35f6-4692-9b61-0c7d964528eb', tool_call_id='call_00_iNkw5TvgsNGIq6fjJ7ak5294'),
#               AIMessage(content='Let me get some more specific, highly-rated recipes for you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 139, 'prompt_tokens': 1304, 'total_tokens': 1443, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 1048}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'e139f429-3c2a-48de-9249-d31c449750c8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e79db-eeaf-7962-be7b-3b077e066e63-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'best chicken fried rice recipe with leftover chicken and rice'}, 'id': 'call_00_0rbzul5Xh6wIOjYwrbM46004', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken rice casserole recipe leftover chicken'}, 'id': 'call_01_gnBkmMG6zVeMszZpi5340432', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe with leftover chicken'}, 'id': 'call_02_ixP3yeYzYMzXzLDRxKKo9809', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1304, 'output_tokens': 139, 'total_tokens': 1443, 'input_token_details': {'cache_read': 256}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "best chicken fried rice recipe with leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.olgasflavorfactory.com/recipes/weeknight-dinners/chicken-fried-rice", "title": "Chicken Fried Rice - Olga\'s Flavor Factory", "content": "Chicken fried rice is one of those meals that’s as satisfying as it is resourceful. It’s my go-to recipe when I’ve got leftover rice hanging around, and if I happen to have some leftover chicken? Not only does it make the most of what you’ve already got, but it’s also a quick and easy way to make a hearty, flavorful meal. What I love most about fried rice is how versatile it is. So, the next time you’re wondering what to do with those leftover chicken and rice, make chicken fried rice! ## How To Make Chicken Fried Rice. Chicken Fried Rice-1-4Add the green beans to the same skillet, season with salt and pepper, pour in about ¼ cup of water, cover the skillet and cook until the green beans are tender but still vibrant green. Chicken Fried Rice-1-6Add 1 Tablespoon of oil into the same skillet and add the onion, carrot and garlic.", "score": 0.8849276, "raw_content": null}, {"url": "https://streetsmartnutrition.com/easy-weeknight-fried-rice", "title": "Rotisserie Chicken Fried Rice For An Easy Weeknight Meal", "content": "*This\xa0**Rotisserie Chicken Fried Rice**\xa0recipe uses, you guessed it, leftover rotisserie chicken with white rice, veggies, and plenty of seasoning! So with that out of the way, let’s get into this recipe for my **Rotisserie Chicken Fried Rice**! This is what inspired this homemade fried rice recipe because my dad always used the leftover rice to make his version of a chicken fried rice recipe the following day. White serving bowl on a trivet, filled high with an easy fried rice recipe with leftover rotisserie chicken, carrots, and green peas. ## How to Make Rotisserie Chicken Fried Rice. While I kept this Rotisserie Chicken Fried Rice recipe simple on purpose, there are plenty of ways to dress it up or customize it! I also love adding a bit of red pepper sauce (like sriracha!) when I serve my rotisserie chicken fried rice, but this is totally optional. I hope you love this\xa0**Rotisserie Chicken Fried Rice**\xa0recipe as much as we do!", "score": 0.86767644, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.8458536, "raw_content": null}, {"url": "https://therecipecritic.com/chicken-fried-rice", "title": "Better than Takeout Chicken Fried Rice | The Recipe Critic", "content": "Home › Side Dishes › **Better than Takeout Chicken Fried Rice**. # Better than Takeout Chicken Fried Rice. This **easy** chicken fried rice! Overhead shot of cooked chicken fried rice in a skillet. ## How To Make Chicken Fried Rice. This chicken fried rice comes together fast and makes the best use of leftovers. Rice and chicken added to the vegetables and eggs in the skillet. Rice and chicken added to the vegetables and eggs in the skillet. **High Heat:**Cooking chicken fried rice over high heat is best for fried rice. Bowl of chicken fried rice with chopsticks. ### **How to Store Leftover Chicken Fried Rice**. ## Chicken Fried Rice. 30-Minute Meals, Appetizers, Asian, Carrot, Chicken, Dinner, Easy, Onion, Pea, Recipe Skill Levels, Side Dishes, Vegetables. I cook the rice the day before used leftover chicken breasts the first time. “you know when you make those PF Changs (he’s talking about the chicken fried rice), it smells exactly like that.” – uh.", "score": 0.8415267, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Re ...
#               ToolMessage(content='{"query": "chicken rice casserole recipe leftover chicken", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Chicken and Rice Casserole - Cleverly Simple", "url": "https://www.cleverlysimple.com/chicken-and-rice-casserole", "content": "# Chicken and Rice Casserole. I love a good casserole recipe. What makes it one of my favorites is the use of already cooked chicken like you’ll find with chicken tetrazzini and chicken pot pie. That’s who my grandma made this for in the past – and whenever there are a few names, I know it was a repeat performer which means it’s going to be good! * **It’s a great rotisserie chicken casserole.** I love using this recipe with my rotisserie chicken; it gives it great flavor with the creamy sauce. **Cooked Chicken** – This is the time to let that leftover chicken shine! You can use this simple chicken and rice casserole recipe or boil 3 chicken breasts for 10-15 minutes and remove when they internally reach 160˚ F. **Cooked Rice** – Your favorite rice is cooked in chicken broth, which adds flavor baked right into the casserole. ## How to Make Chicken and Rice Casserole.", "score": 0.9999738, "raw_content": null}, {"title": "Chicken Rice Casserole Recipe - Food.com", "url": "https://www.food.com/recipe/chicken-rice-casserole-118072", "content": "# Chicken Rice Casserole. \\"A great use for leftover chicken or turkey. A creamy wonderful one dish meal of chicken, rice \'n peas, topped off with a mixture of bread crumbs and Parmesan cheese and baked until golden brown.\\". * Spread rice in prepared baking dish, sprinkle with the peas and then pour creamed chicken mixture over. You can use broccoli, or green beans instead of peas or a bag of peas and carrots frozen..I often use some slivered or flat cut almonds on top...for crunch...also I think water chestnuts would be good ..stirred into the chicken mix...`. I poured 1/2 cup broth on the rice before adding the chicken mixture and used Panko breadcrumbs on top along with fair amount of finely grated Parmesan cheese. But I think next time I make it, I will add a bit of chopped onion and garlic for a little more flavor, plus a little more bread crumbs and Parmesan cheese on the top.", "score": 0.99996436, "raw_content": null}, {"title": "Leftovers: Chicken and Rice Casserole - Putting It All On The Table", "url": "https://puttingitallonthetable.com/leftovers-chicken-and-rice-casserole", "content": "Cook until starting to brown, about 5 minutes. Stir in flour and cook for one minute. Whisk in milk and broth and cook until it thickens. Stir in cheese, thyme, salt, pepper and mustard, stirring until cheese melts. Stir in chicken and peas. Spread rice in the baking pan.", "score": 0.99989104, "raw_content": null}, {"title": "Chicken Rice Casserole Recipe - Add a Pinch", "url": "https://addapinch.com/chicken-rice-casserole-recipe-2", "content": "# Chicken Rice Casserole Recipe. Growing up, there were certain dishes that we could depend on having in the way of comfort food:\xa0chicken and dumplings when it was cold or rainy, chicken soup when we didn’t feel well, and ***chicken and rice casserole*** to carry to friends and neighbors when they needed a meal to celebrate the birth of a child or mourn the loss of a loved one and everything in between, it seems. * **Easy recipe.** It uses simple ingredients that are easily combined and baked in a baking dish for a one dish meal. You will need a few simple ingredients to make this chicken rice casserole. * **chicken** – you will need 2 cups of shredded chicken for this recipe. * **rice** – you’ll need 2 cups of cooked rice. * **cream of chicken soup** – you will need 2 cups of cream of chicken soup.", "score": 0.999826, "raw_content": null}, {"title": "Chicken and Rice Casserole - The Country Cook", "url": "https://www.thecountrycook.net/chicken-and-rice-casserole", "content": "# Chicken and Rice Casserole. This recipe for Chicken and Rice Casserole ...
#               ToolMessage(content='{"query": "chicken and rice soup recipe with leftover chicken", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/359449298384504/posts/1616828732646548", "title": "Making chicken and rice soup with leftover chicken - Facebook", "content": "Dice the leftover chicken while boiling the rice. Put a cup of milk in a saucepan and add a can of cream of chicken soup. As milk/soup mixture", "score": 0.93735445, "raw_content": null}, {"url": "https://www.landolakes.com/recipe/9681/super-easy-chicken-rice-soup", "title": "Super Easy Chicken & Rice Soup Recipe | Land O’Lakes", "content": "Super Easy Chicken & Rice Soup. # Super Easy Chicken & Rice Soup. Use leftover rice and purchase a rotisserie chicken to make this simple and satisfying soup. Use leftover rice and purchase a rotisserie chicken to make this simple and satisfying soup. You now are able to shop & buy these ingredients online! After you select your market, you decide if you want to have your items delivered or picked up today! ## Ingredients. cooked rice, white, brown, wild or mix of varieties. Add onion, celery, carrots and garlic; continue cooking 3-5 minutes or until onion is softened. Continue cooking, stirring occasionally, 7-9 minutes or until mixture comes to a boil and carrots are tender. Stir in rice, chicken and parsley. ### More Recipes To Make. ## Rice Recipes. Whether it’s main dishes or sides, rice helps make an easy meal. Our recipes feature different rice varieties and flavors so there\'s something for everyone! Sign up for our newsletter today!", "score": 0.92074, "raw_content": null}, {"url": "https://entertainingwithbeth.com/easy-chicken-and-rice-soup", "title": "Easy Chicken and Rice Soup - Entertaining with Beth", "content": "Made with store-bought rotisserie chicken, or leftover chicken, and microwavable rice this is a delicious 15-minute meal!", "score": 0.8815438, "raw_content": null}, {"url": "https://www.foodnetwork.com/recipes/nancy-fuller/chicken-and-rice-soup-2399313", "title": "Chicken and Rice Soup Recipe | Nancy Fuller - Food Network", "content": "For the leftover roast chicken stock: Put the cleaned chicken carcass in a large saucepan along with the salt, peppercorns, celery, bay leaf, carrots and onions", "score": 0.8800674, "raw_content": null}, {"url": "https://thecafesucrefarine.com/the-best-chicken-and-rice-soup", "title": "The BEST Chicken and Rice Soup - The Café Sucre Farine", "content": "This really is one of the best, most flavorful chicken and rice soups we\'ve ever tasted! ***This really is one of the best, most flavorful chicken and rice soups we\'ve ever tasted! That\'s why I created this easy chicken and rice soup recipe that utilizes and rotisserie (or leftover) chicken along with a few little tricks to ensure a super flavorful broth without making it totally-from-scratch. You might be wondering why the rice is added at the very end in this chicken and rice soup recipe. ## Café Tips for making this Chicken and Rice Soup. * This chicken and rice soup recipe calls for a teaspoon of turmeric. This really is one of the best, most flavorful chicken and rice soups we\'ve ever tasted! 7. Remove the bay leaves then add the rotisserie chicken, rosemary, cooked rice and finely chopped spinach (if using). My family and I love this chicken and rice recipe....delicious!", "score": 0.8752871, "raw_content": null}], "response_time": 0.9, "request_id": "2c4b35da-a5bb-4593-a7d4-cd33377a2ce4"}', name='web_search', id='16ee5d63-f7bb-4396-8369-981fa969ccb5', tool_call_id='call_02_ixP3yeYzYMzXzLDRxKKo9809'),
#               AIMessage(content="Here are some fantastic recipe ideas you can make with leftover chicken and rice! Let me know if any catch your interest and I'll give you the full details.\n\n---\n\n## 🍳 Recipe Ideas for Leftover Chicken & Rice\n\n### 1. **Chicken Fried Rice** ⭐ (Most Popular)\nA quick one-pan meal that beats takeout! Just stir-fry your chicken and rice with veggies, soy sauce, and eggs.\n- **Key ingredients you may need:** Soy sauce, eggs, frozen peas & carrots, garlic, sesame oil\n- ⏱ Time: ~15-20 minutes\n\n### 2. **Chicken & Rice Casserole**\nA creamy, cheesy comfort food classic. Mix your chicken and rice with cream of chicken soup, veggies, and cheese, then bake with breadcrumbs on top.\n- **Key ingredients you may need:** Cream of chicken soup, cheese, peas, breadcrumbs/butter topping\n- ⏱ Time: ~30-40 minutes\n\n### 3. **Chicken & Rice Soup**\nWarm, soothing, and easy! Simmer your chicken and rice in broth with carrots, celery, and onion for a hearty soup.\n- **Key ingredients you may need:** Chicken broth, carrots, celery, onion, garlic\n- ⏱ Time: ~20-25 minutes\n\n### 4. **Chicken Rice Bowl**\nLayer your chicken and rice with your favorite toppings — avocado, salsa, black beans, cheese, sour cream, or roasted veggies.\n- **Key ingredients you may need:** Whatever toppings you have on hand!\n- ⏱ Time: ~5-10 minutes (no cooking required)\n\n### 5. **Chicken Rice Stuffed Peppers**\nMix chicken, rice, cheese, and spices, stuff into bell peppers, and bake.\n- **Key ingredients you may need:** Bell peppers, cheese, tomato sauce, onion\n- ⏱ Time: ~30-40 minutes\n\n---\n\nDo any of these sound good to you? I can pull up the **full recipe instructions** for whichever one you'd like to make! Also, let me know if you have any other ingredients on hand (veggies, spices, sauces, etc.) and I can tailor the suggestions even more.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 466, 'prompt_tokens': 4786, 'total_tokens': 5252, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1408}, 'prompt_cache_hit_tokens': 1408, 'prompt_cache_miss_tokens': 3378}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'fefbfcbd-76ed-421c-bbe0-3bcc592c3d0b', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e79dc-0445-7590-83f7-eeea1d8958e5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4786, 'output_tokens': 466, 'total_tokens': 5252, 'input_token_details': {'cache_read': 1408}, 'output_token_details': {}})]}
